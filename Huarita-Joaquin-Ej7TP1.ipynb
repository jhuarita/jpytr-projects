# %% [markdown]
# # Tarea Semanal 1
# ## Huarita, Joaquín
# ### Ejercicio 7 TP1
#
# ![Captura%20de%20pantalla%20de%202021-04-16%2011-37-23.png](attachment:Captura%20de%20pantalla%20de%202021-04-16%2011-37-23.png)
#
# $\frac{V2(s)}{V1(s)}=?$

# %% [markdown]
# #### Desarrollo Matematico
# ![WhatsApp%20Image%202021-04-16%20at%2017.10.52.jpeg](attachment:WhatsApp%20Image%202021-04-16%20at%2017.10.52.jpeg)

# %% [markdown]
# #### Simulacion Matematica

# %%
from scipy import signal
import matplotlib.pyplot as plt
from splane import bodePlot, pzmap
import numpy as np

R=1000
C=0.000001

wo=np.arange(1, 10**5, 10)
sys = signal.TransferFunction([-C*R,1], [C*R,1])
w, mag, phase = signal.bode(sys,wo)

plt.figure()
plt.semilogx(w, mag)    # Diagrama de bode en magnitud
plt.ylim([-1,1])

plt.figure()
plt.semilogx(w, phase)  # Diagrama de bode en fase

pzmap(sys)              # Diagrama de Polos y Ceros

plt.show()

# %% [markdown]
# #### Simulacion Circuital
# ![Captura%20de%20pantalla%20de%202021-04-16%2017-03-50.png](attachment:Captura%20de%20pantalla%20de%202021-04-16%2017-03-50.png)
#
# Debido al comportamiento real del operacional LM741 se pudo observar que la fase rota aproximadamente 115°. Y ademas el ancho de banda de operación del mismo es alrededor de 1MHz.
